# %%
# Verify that you have the GPU recognized
# !nvidia-smi
# Out:
# Fri Mar 14 21:35:59 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # Git clone COMP9312 repo

# %%
# !rm -rf /content/COMP9312
# !git clone https://github.com/mohammedkhalilia/COMP9312.git
# Out:
# Cloning into 'COMP9312'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 107 (delta 19), reused 55 (delta 14), pack-reused 43 (from 1)
# Receiving objects: 100% (107/107), 276.57 KiB | 8.64 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %% [markdown]
# # Install dependencies

# %%
# !pip install transformers==4.40.2
# !pip install seqeval==1.2.2
# !pip install torchtext==0.18.0
# !pip install torchvision==0.17.2
# !pip install torch==2.3.0
# Out:
# Collecting transformers==4.40.2
#   Downloading transformers-4.40.2-py3-none-any.whl.metadata (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.40.2) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.11/dist-packages (from transformers==4.40.2) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.40.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.40.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.40.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.40.2) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.40.2) (2.32.3)
# Collecting tokenizers<0.20,>=0.19 (from transformers==4.40.2)
#   Downloading tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.40.2) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.40.2) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.40.2) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.40.2) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.40.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.40.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.40.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.40.2) (2025.1.31)
# Downloading transformers-4.40.2-py3-none-any.whl (9.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 62.6 MB/s eta 0:00:00
# Downloading tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 95.6 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.0
#     Uninstalling tokenizers-0.21.0:
#       Successfully uninstalled tokenizers-0.21.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.48.3
#     Uninstalling transformers-4.48.3:
#       Successfully uninstalled transformers-4.48.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.40.2 which is incompatible.
# Successfully installed tokenizers-0.19.1 transformers-4.40.2
# Collecting seqeval==1.2.2
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from seqeval==1.2.2) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.11/dist-packages (from seqeval==1.2.2) (1.6.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.21.3->seqeval==1.2.2) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.21.3->seqeval==1.2.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.21.3->seqeval==1.2.2) (3.5.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16161 sha256=a930ad0e26a17cf58757fe173fbfff18c289372fca41606e04c4d4468a347d20
#   Stored in directory: /root/.cache/pip/wheels/bc/92/f0/243288f899c2eacdfa8c5f9aede4c71a9bad0ee26a01dc5ead
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2
# Collecting torchtext==0.18.0
#   Downloading torchtext-0.18.0-cp311-cp311-manylinux1_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torchtext==0.18.0) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchtext==0.18.0) (2.32.3)
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from torchtext==0.18.0) (2.6.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchtext==0.18.0) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18.0) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18.0) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18.0) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.3.0->torchtext==0.18.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.3.0->torchtext==0.18.0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.3.0->torchtext==0.18.0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.3.0->torchtext==0.18.0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.3.0->torchtext==0.18.0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.3.0->torchtext==0.18.0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.3.0->torchtext==0.18.0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.3.0->torchtext==0.18.0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.3.0->torchtext==0.18.0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18.0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.3.0->torchtext==0.18.0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext==0.18.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.3.0->torchtext==0.18.0) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.18.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.18.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.18.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.18.0) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.3.0->torchtext==0.18.0) (3.0.2)
# Downloading torchtext-0.18.0-cp311-cp311-manylinux1_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 31.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 65.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 50.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 823.6 kB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 75.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchtext
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 torchtext-0.18.0
# Collecting torchvision==0.17.2
#   Downloading torchvision-0.17.2-cp311-cp311-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.17.2) (1.26.4)
# Collecting torch==2.2.2 (from torchvision==0.17.2)
#   Downloading torch-2.2.2-cp311-cp311-manylinux1_x86_64.whl.metadata (25 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.17.2) (11.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2->torchvision==0.17.2) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2->torchvision==0.17.2) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2->torchvision==0.17.2) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2->torchvision==0.17.2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2->torchvision==0.17.2) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.2.2->torchvision==0.17.2) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.2->torchvision==0.17.2)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.2->torchvision==0.17.2)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.2->torchvision==0.17.2)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.2->torchvision==0.17.2)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.2->torchvision==0.17.2)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.2->torchvision==0.17.2)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.2->torchvision==0.17.2)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.2->torchvision==0.17.2)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.2->torchvision==0.17.2)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.2->torchvision==0.17.2)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.2->torchvision==0.17.2)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.2.0 (from torch==2.2.2->torchvision==0.17.2)
#   Downloading triton-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.2->torchvision==0.17.2) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.2.2->torchvision==0.17.2) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.2.2->torchvision==0.17.2) (1.3.0)
# Downloading torchvision-0.17.2-cp311-cp311-manylinux1_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 15.7 MB/s eta 0:00:00
# Downloading torch-2.2.2-cp311-cp311-manylinux1_x86_64.whl (755.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 102.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 92.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 49.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 12.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.4 MB/s eta 0:00:00
# Downloading triton-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 6.6 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusolver-cu12, nvidia-cudnn-cu12, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.3.1.170
#     Uninstalling nvidia-cusparse-cu12-12.3.1.170:
#       Successfully uninstalled nvidia-cusparse-cu12-12.3.1.170
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.5.147
#     Uninstalling nvidia-curand-cu12-10.3.5.147:
#       Successfully uninstalled nvidia-curand-cu12-10.3.5.147
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.1.3
#     Uninstalling nvidia-cufft-cu12-11.2.1.3:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.1.3
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.4.127
#     Uninstalling nvidia-cuda-runtime-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.4.127
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.4.127
#     Uninstalling nvidia-cuda-cupti-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.4.127
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.4.5.8
#     Uninstalling nvidia-cublas-cu12-12.4.5.8:
#       Successfully uninstalled nvidia-cublas-cu12-12.4.5.8
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.1.9
#     Uninstalling nvidia-cusolver-cu12-11.6.1.9:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.1.9
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.1.0.70
#     Uninstalling nvidia-cudnn-cu12-9.1.0.70:
#       Successfully uninstalled nvidia-cudnn-cu12-9.1.0.70
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.21.0+cu124
#     Uninstalling torchvision-0.21.0+cu124:
#       Successfully uninstalled torchvision-0.21.0+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 2.2.2 which is incompatible.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.2.2 which is incompatible.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.40.2 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvtx-cu12-12.1.105 torch-2.2.2 torchvision-0.17.2 triton-2.2.0
# Collecting torch==2.3.0
#   Downloading torch-2.3.0-cp311-cp311-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (12.1.0.106)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.3.0)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (12.1.105)
# Collecting triton==2.3.0 (from torch==2.3.0)
#   Downloading triton-2.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.0) (12.4.127)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.3.0) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.3.0) (1.3.0)
# Downloading torch-2.3.0-cp311-cp311-manylinux1_x86_64.whl (779.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.2/779.2 MB 1.2 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.3 MB/s eta 0:00:00
# Downloading triton-2.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 6.1 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-nccl-cu12, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 2.2.0
#     Uninstalling triton-2.2.0:
#       Successfully uninstalled triton-2.2.0
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.19.3
#     Uninstalling nvidia-nccl-cu12-2.19.3:
#       Successfully uninstalled nvidia-nccl-cu12-2.19.3
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.2
#     Uninstalling torch-2.2.2:
#       Successfully uninstalled torch-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.17.2 requires torch==2.2.2, but you have torch 2.3.0 which is incompatible.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.3.0 which is incompatible.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.40.2 which is incompatible.
# Successfully installed nvidia-nccl-cu12-2.20.5 torch-2.3.0 triton-2.3.0

# %% [markdown]
# # Model training

# %%
# Make output directory
# !mkdir /content/output/

# %%
import sys
import argparse
sys.path.append('/content/COMP9312/')

# %%
from comp9312.classify.train import main
# Out:
# /usr/local/lib/python3.11/dist-packages/torchtext/vocab/__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# /usr/local/lib/python3.11/dist-packages/torchtext/utils.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)

# %%
# Hyperparameters you can tune include:
#  max_epochs: number of epochs for trianing the model
#  batch_size: size of the batch depending on how much memory you have
#  learning_rate: try small changes for the learning rate, i.e. 0.00002, 0.00003. 0.00004, 0.00005
#  bert_model: there are many different pre-trained BERT models for Arabic and I encourage you try different ones, this includes:
#              1. aubmindlab/bert-base-arabertv2
#              2. UBC-NLP/ARBERTv2
#              3. UBC-NLP/MARBERT
#              4. CAMeL-Lab/bert-base-arabic-camelbert-da
#              5. CAMeL-Lab/bert-base-arabic-camelbert-mix-ner


args_dict = {
    "output_path": "/content/output/",
    "train_path": "/content/COMP9312/comp9312/data/AJGT/train.csv",
    "test_path": "/content/COMP9312/comp9312/data/AJGT/test.csv",
    "val_path": "/content/COMP9312/comp9312/data/AJGT/val.csv",
    "seed": 1,
    "max_epochs": 4,
    "batch_size": 8,
    "bert_model": "aubmindlab/bert-base-arabertv2",
    "num_workers": 1,
    "gpus": [0],
    "learning_rate": .00005
}
args = argparse.Namespace()
args.__dict__ = args_dict

# %%
main(args)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:32	Epoch 0 | Batch 10/158 | Timestep 10 | Loss 0.710081
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:33	Epoch 0 | Batch 20/158 | Timestep 20 | Loss 0.700406
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:34	Epoch 0 | Batch 30/158 | Timestep 30 | Loss 0.628637
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:35	Epoch 0 | Batch 40/158 | Timestep 40 | Loss 0.330945
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:36	Epoch 0 | Batch 50/158 | Timestep 50 | Loss 0.378028
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:37	Epoch 0 | Batch 60/158 | Timestep 60 | Loss 0.700037
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:38	Epoch 0 | Batch 70/158 | Timestep 70 | Loss 0.289532
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:39	Epoch 0 | Batch 80/158 | Timestep 80 | Loss 0.503869
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:40	Epoch 0 | Batch 90/158 | Timestep 90 | Loss 0.311299
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:41	Epoch 0 | Batch 100/158 | Timestep 100 | Loss 0.356444
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:42	Epoch 0 | Batch 110/158 | Timestep 110 | Loss 0.083275
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:43	Epoch 0 | Batch 120/158 | Timestep 120 | Loss 0.176363
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:44	Epoch 0 | Batch 130/158 | Timestep 130 | Loss 0.149386
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:45	Epoch 0 | Batch 140/158 | Timestep 140 | Loss 0.322323
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:46	Epoch 0 | Batch 150/158 | Timestep 150 | Loss 0.348821
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:47	** Evaluating on validation dataset **
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:47
#               precision    recall  f1-score   support
#
#     Negative       0.88      0.96      0.91        90
#     Positive       0.95      0.87      0.91        90
#
#     accuracy                           0.91       180
#    macro avg       0.91      0.91      0.91       180
# weighted avg       0.91      0.91      0.91       180
#
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:47	Epoch 0 | Timestep 158 | Train Loss 0.417194 | Val Loss 0.248456 | F1 Micro 0.911111
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:47	** Validation improved, evaluating test data **
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:49
#               precision    recall  f1-score   support
#
#     Negative       0.87      0.96      0.91       178
#     Positive       0.95      0.86      0.90       182
#
#     accuracy                           0.91       360
#    macro avg       0.91      0.91      0.91       360
# weighted avg       0.91      0.91      0.91       360
#
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:49	Epoch 0 | Timestep 158 | Test Loss 0.239746 | F1 Micro 0.905556
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:52:49	Saving checkpoint to /content/output/model.pt
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:09	Epoch 1 | Batch 2/158 | Timestep 160 | Loss 0.047975
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:10	Epoch 1 | Batch 12/158 | Timestep 170 | Loss 0.222528
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:11	Epoch 1 | Batch 22/158 | Timestep 180 | Loss 0.331568
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:12	Epoch 1 | Batch 32/158 | Timestep 190 | Loss 0.123513
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:13	Epoch 1 | Batch 42/158 | Timestep 200 | Loss 0.129895
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:14	Epoch 1 | Batch 52/158 | Timestep 210 | Loss 0.020764
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:15	Epoch 1 | Batch 62/158 | Timestep 220 | Loss 0.048245
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:16	Epoch 1 | Batch 72/158 | Timestep 230 | Loss 0.181512
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:17	Epoch 1 | Batch 82/158 | Timestep 240 | Loss 0.535449
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:18	Epoch 1 | Batch 92/158 | Timestep 250 | Loss 0.458681
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:19	Epoch 1 | Batch 102/158 | Timestep 260 | Loss 0.013498
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:20	Epoch 1 | Batch 112/158 | Timestep 270 | Loss 0.012657
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:21	Epoch 1 | Batch 122/158 | Timestep 280 | Loss 0.555812
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:22	Epoch 1 | Batch 132/158 | Timestep 290 | Loss 0.036328
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:23	Epoch 1 | Batch 142/158 | Timestep 300 | Loss 0.136792
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:24	Epoch 1 | Batch 152/158 | Timestep 310 | Loss 0.369583
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:25	** Evaluating on validation dataset **
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:26
#               precision    recall  f1-score   support
#
#     Negative       0.97      0.78      0.86        90
#     Positive       0.81      0.98      0.89        90
#
#     accuracy                           0.88       180
#    macro avg       0.89      0.88      0.88       180
# weighted avg       0.89      0.88      0.88       180
#
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:26	Epoch 1 | Timestep 316 | Train Loss 0.172209 | Val Loss 0.454139 | F1 Micro 0.877778
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:26	Epoch 2 | Batch 4/158 | Timestep 320 | Loss 0.012769
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:27	Epoch 2 | Batch 14/158 | Timestep 330 | Loss 0.006182
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:28	Epoch 2 | Batch 24/158 | Timestep 340 | Loss 0.006451
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:29	Epoch 2 | Batch 34/158 | Timestep 350 | Loss 0.470344
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:30	Epoch 2 | Batch 44/158 | Timestep 360 | Loss 0.005151
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:31	Epoch 2 | Batch 54/158 | Timestep 370 | Loss 0.009857
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:32	Epoch 2 | Batch 64/158 | Timestep 380 | Loss 0.069045
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:33	Epoch 2 | Batch 74/158 | Timestep 390 | Loss 0.020007
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:34	Epoch 2 | Batch 84/158 | Timestep 400 | Loss 0.010177
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:35	Epoch 2 | Batch 94/158 | Timestep 410 | Loss 0.004037
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:36	Epoch 2 | Batch 104/158 | Timestep 420 | Loss 0.004116
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:37	Epoch 2 | Batch 114/158 | Timestep 430 | Loss 0.008368
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:38	Epoch 2 | Batch 124/158 | Timestep 440 | Loss 0.021112
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:39	Epoch 2 | Batch 134/158 | Timestep 450 | Loss 0.018751
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:40	Epoch 2 | Batch 144/158 | Timestep 460 | Loss 0.025343
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:41	Epoch 2 | Batch 154/158 | Timestep 470 | Loss 0.027323
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:42	** Evaluating on validation dataset **
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:42
#               precision    recall  f1-score   support
#
#     Negative       0.86      0.90      0.88        90
#     Positive       0.90      0.86      0.88        90
#
#     accuracy                           0.88       180
#    macro avg       0.88      0.88      0.88       180
# weighted avg       0.88      0.88      0.88       180
#
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:42	Epoch 2 | Timestep 474 | Train Loss 0.083800 | Val Loss 0.339616 | F1 Micro 0.877778
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:43	Epoch 3 | Batch 6/158 | Timestep 480 | Loss 0.031734
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:44	Epoch 3 | Batch 16/158 | Timestep 490 | Loss 0.011896
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:45	Epoch 3 | Batch 26/158 | Timestep 500 | Loss 0.006195
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:46	Epoch 3 | Batch 36/158 | Timestep 510 | Loss 0.006430
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:47	Epoch 3 | Batch 46/158 | Timestep 520 | Loss 0.007775
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:48	Epoch 3 | Batch 56/158 | Timestep 530 | Loss 0.003235
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:49	Epoch 3 | Batch 66/158 | Timestep 540 | Loss 0.008722
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:50	Epoch 3 | Batch 76/158 | Timestep 550 | Loss 0.680019
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:51	Epoch 3 | Batch 86/158 | Timestep 560 | Loss 0.031627
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:52	Epoch 3 | Batch 96/158 | Timestep 570 | Loss 0.008367
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:53	Epoch 3 | Batch 106/158 | Timestep 580 | Loss 0.119181
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:54	Epoch 3 | Batch 116/158 | Timestep 590 | Loss 0.250529
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:55	Epoch 3 | Batch 126/158 | Timestep 600 | Loss 0.004935
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:57	Epoch 3 | Batch 136/158 | Timestep 610 | Loss 0.013121
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:58	Epoch 3 | Batch 146/158 | Timestep 620 | Loss 0.043736
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:59	Epoch 3 | Batch 156/158 | Timestep 630 | Loss 0.027267
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:59	** Evaluating on validation dataset **
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:59
#               precision    recall  f1-score   support
#
#     Negative       0.87      0.87      0.87        90
#     Positive       0.87      0.87      0.87        90
#
#     accuracy                           0.87       180
#    macro avg       0.87      0.87      0.87       180
# weighted avg       0.87      0.87      0.87       180
#
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:53:59	Epoch 3 | Timestep 632 | Train Loss 0.098181 | Val Loss 0.515468 | F1 Micro 0.866667

# %%
# Hyperparameters you can tune include:
#  max_epochs: number of epochs for trianing the model
#  batch_size: size of the batch depending on how much memory you have
#  learning_rate: try small changes for the learning rate, i.e. 0.00002, 0.00003. 0.00004, 0.00005
#  bert_model: there are many different pre-trained BERT models for Arabic and I encourage you try different ones, this includes:
#              1. aubmindlab/bert-base-arabertv2
#              2. UBC-NLP/ARBERTv2
#              3. UBC-NLP/MARBERT
#              4. CAMeL-Lab/bert-base-arabic-camelbert-da
#              5. CAMeL-Lab/bert-base-arabic-camelbert-mix-ner


args_dict = {
    "output_path": "/content/output/",
    "train_path": "/content/COMP9312/comp9312/data/AJGT/train.csv",
    "test_path": "/content/COMP9312/comp9312/data/AJGT/test.csv",
    "val_path": "/content/COMP9312/comp9312/data/AJGT/val.csv",
    "seed": 1,
    "max_epochs": 4,
    "batch_size": 8,
    "bert_model": "aubmindlab/bert-base-arabertv2",
    "num_workers": 1,
    "gpus": [0],
    "learning_rate": .000075
}
args = argparse.Namespace()
args.__dict__ = args_dict

# %%
main(args)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:02	Epoch 0 | Batch 10/158 | Timestep 10 | Loss 0.826722
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:03	Epoch 0 | Batch 20/158 | Timestep 20 | Loss 0.834243
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:04	Epoch 0 | Batch 30/158 | Timestep 30 | Loss 0.585980
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:05	Epoch 0 | Batch 40/158 | Timestep 40 | Loss 0.196167
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:06	Epoch 0 | Batch 50/158 | Timestep 50 | Loss 0.552104
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:07	Epoch 0 | Batch 60/158 | Timestep 60 | Loss 0.475476
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:08	Epoch 0 | Batch 70/158 | Timestep 70 | Loss 0.378766
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:09	Epoch 0 | Batch 80/158 | Timestep 80 | Loss 0.319417
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:10	Epoch 0 | Batch 90/158 | Timestep 90 | Loss 0.248443
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:11	Epoch 0 | Batch 100/158 | Timestep 100 | Loss 0.508759
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:12	Epoch 0 | Batch 110/158 | Timestep 110 | Loss 0.459295
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:13	Epoch 0 | Batch 120/158 | Timestep 120 | Loss 0.336561
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:14	Epoch 0 | Batch 130/158 | Timestep 130 | Loss 0.272355
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:15	Epoch 0 | Batch 140/158 | Timestep 140 | Loss 0.481028
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:16	Epoch 0 | Batch 150/158 | Timestep 150 | Loss 0.273292
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:17	** Evaluating on validation dataset **
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:18
#               precision    recall  f1-score   support
#
#     Negative       0.85      0.93      0.89        90
#     Positive       0.93      0.83      0.88        90
#
#     accuracy                           0.88       180
#    macro avg       0.89      0.88      0.88       180
# weighted avg       0.89      0.88      0.88       180
#
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:18	Epoch 0 | Timestep 158 | Train Loss 0.444076 | Val Loss 0.289994 | F1 Micro 0.883333
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:18	** Validation improved, evaluating test data **
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:19
#               precision    recall  f1-score   support
#
#     Negative       0.89      0.96      0.92       178
#     Positive       0.96      0.88      0.92       182
#
#     accuracy                           0.92       360
#    macro avg       0.92      0.92      0.92       360
# weighted avg       0.92      0.92      0.92       360
#
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:19	Epoch 0 | Timestep 158 | Test Loss 0.221654 | F1 Micro 0.919444
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:19	Saving checkpoint to /content/output/model.pt
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:25	Epoch 1 | Batch 2/158 | Timestep 160 | Loss 0.100264
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:26	Epoch 1 | Batch 12/158 | Timestep 170 | Loss 0.208127
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:27	Epoch 1 | Batch 22/158 | Timestep 180 | Loss 0.274448
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:28	Epoch 1 | Batch 32/158 | Timestep 190 | Loss 0.188814
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:29	Epoch 1 | Batch 42/158 | Timestep 200 | Loss 0.048790
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:30	Epoch 1 | Batch 52/158 | Timestep 210 | Loss 0.039852
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:31	Epoch 1 | Batch 62/158 | Timestep 220 | Loss 0.074372
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:32	Epoch 1 | Batch 72/158 | Timestep 230 | Loss 0.120284
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:33	Epoch 1 | Batch 82/158 | Timestep 240 | Loss 0.212296
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:34	Epoch 1 | Batch 92/158 | Timestep 250 | Loss 0.085239
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:35	Epoch 1 | Batch 102/158 | Timestep 260 | Loss 0.027057
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:36	Epoch 1 | Batch 112/158 | Timestep 270 | Loss 0.028969
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:37	Epoch 1 | Batch 122/158 | Timestep 280 | Loss 0.067682
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:38	Epoch 1 | Batch 132/158 | Timestep 290 | Loss 0.143402
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:40	Epoch 1 | Batch 142/158 | Timestep 300 | Loss 0.234540
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:40	Epoch 1 | Batch 152/158 | Timestep 310 | Loss 0.213017
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:41	** Evaluating on validation dataset **
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:42
#               precision    recall  f1-score   support
#
#     Negative       0.83      0.97      0.89        90
#     Positive       0.96      0.80      0.87        90
#
#     accuracy                           0.88       180
#    macro avg       0.89      0.88      0.88       180
# weighted avg       0.89      0.88      0.88       180
#
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:42	Epoch 1 | Timestep 316 | Train Loss 0.203345 | Val Loss 0.491687 | F1 Micro 0.883333
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:42	Epoch 2 | Batch 4/158 | Timestep 320 | Loss 0.327717
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:43	Epoch 2 | Batch 14/158 | Timestep 330 | Loss 0.124663
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:44	Epoch 2 | Batch 24/158 | Timestep 340 | Loss 0.037961
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:45	Epoch 2 | Batch 34/158 | Timestep 350 | Loss 0.052979
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:46	Epoch 2 | Batch 44/158 | Timestep 360 | Loss 0.008689
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:47	Epoch 2 | Batch 54/158 | Timestep 370 | Loss 0.083352
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:48	Epoch 2 | Batch 64/158 | Timestep 380 | Loss 0.022819
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:49	Epoch 2 | Batch 74/158 | Timestep 390 | Loss 0.024594
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:50	Epoch 2 | Batch 84/158 | Timestep 400 | Loss 0.035550
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:51	Epoch 2 | Batch 94/158 | Timestep 410 | Loss 0.021372
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:52	Epoch 2 | Batch 104/158 | Timestep 420 | Loss 0.032301
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:53	Epoch 2 | Batch 114/158 | Timestep 430 | Loss 0.021391
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:54	Epoch 2 | Batch 124/158 | Timestep 440 | Loss 0.074422
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:55	Epoch 2 | Batch 134/158 | Timestep 450 | Loss 0.048517
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:56	Epoch 2 | Batch 144/158 | Timestep 460 | Loss 0.005921
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:58	Epoch 2 | Batch 154/158 | Timestep 470 | Loss 0.057967
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:58	** Evaluating on validation dataset **
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:59
#               precision    recall  f1-score   support
#
#     Negative       0.91      0.80      0.85        90
#     Positive       0.82      0.92      0.87        90
#
#     accuracy                           0.86       180
#    macro avg       0.87      0.86      0.86       180
# weighted avg       0.87      0.86      0.86       180
#
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:59	Epoch 2 | Timestep 474 | Train Loss 0.118085 | Val Loss 0.603632 | F1 Micro 0.861111
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:54:59	Epoch 3 | Batch 6/158 | Timestep 480 | Loss 0.012680
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:00	Epoch 3 | Batch 16/158 | Timestep 490 | Loss 0.009880
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:01	Epoch 3 | Batch 26/158 | Timestep 500 | Loss 0.007294
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:02	Epoch 3 | Batch 36/158 | Timestep 510 | Loss 0.139881
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:03	Epoch 3 | Batch 46/158 | Timestep 520 | Loss 0.025170
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:04	Epoch 3 | Batch 56/158 | Timestep 530 | Loss 0.010452
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:05	Epoch 3 | Batch 66/158 | Timestep 540 | Loss 0.017530
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:06	Epoch 3 | Batch 76/158 | Timestep 550 | Loss 0.014027
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:07	Epoch 3 | Batch 86/158 | Timestep 560 | Loss 0.029633
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:08	Epoch 3 | Batch 96/158 | Timestep 570 | Loss 0.017927
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:09	Epoch 3 | Batch 106/158 | Timestep 580 | Loss 0.011283
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:10	Epoch 3 | Batch 116/158 | Timestep 590 | Loss 0.431172
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:11	Epoch 3 | Batch 126/158 | Timestep 600 | Loss 0.043286
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:13	Epoch 3 | Batch 136/158 | Timestep 610 | Loss 0.017307
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:14	Epoch 3 | Batch 146/158 | Timestep 620 | Loss 0.117989
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:15	Epoch 3 | Batch 156/158 | Timestep 630 | Loss 0.006399
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:15	** Evaluating on validation dataset **
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:15
#               precision    recall  f1-score   support
#
#     Negative       0.81      0.96      0.88        90
#     Positive       0.95      0.78      0.85        90
#
#     accuracy                           0.87       180
#    macro avg       0.88      0.87      0.87       180
# weighted avg       0.88      0.87      0.87       180
#
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:15	Epoch 3 | Timestep 632 | Train Loss 0.080243 | Val Loss 0.624690 | F1 Micro 0.866667

# %%
# Hyperparameters you can tune include:
#  max_epochs: number of epochs for trianing the model
#  batch_size: size of the batch depending on how much memory you have
#  learning_rate: try small changes for the learning rate, i.e. 0.00002, 0.00003. 0.00004, 0.00005
#  bert_model: there are many different pre-trained BERT models for Arabic and I encourage you try different ones, this includes:
#              1. aubmindlab/bert-base-arabertv2
#              2. UBC-NLP/ARBERTv2
#              3. UBC-NLP/MARBERT
#              4. CAMeL-Lab/bert-base-arabic-camelbert-da
#              5. CAMeL-Lab/bert-base-arabic-camelbert-mix-ner


args_dict = {
    "output_path": "/content/output/",
    "train_path": "/content/COMP9312/comp9312/data/AJGT/train.csv",
    "test_path": "/content/COMP9312/comp9312/data/AJGT/test.csv",
    "val_path": "/content/COMP9312/comp9312/data/AJGT/val.csv",
    "seed": 1,
    "max_epochs": 4,
    "batch_size": 8,
    "bert_model": "aubmindlab/bert-base-arabertv2",
    "num_workers": 1,
    "gpus": [0],
    "learning_rate": .0001
}
args = argparse.Namespace()
args.__dict__ = args_dict

# %%
main(args)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:18	Epoch 0 | Batch 10/158 | Timestep 10 | Loss 0.861171
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:19	Epoch 0 | Batch 20/158 | Timestep 20 | Loss 0.815177
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:20	Epoch 0 | Batch 30/158 | Timestep 30 | Loss 0.537471
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:21	Epoch 0 | Batch 40/158 | Timestep 40 | Loss 0.322932
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:22	Epoch 0 | Batch 50/158 | Timestep 50 | Loss 0.316682
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:23	Epoch 0 | Batch 60/158 | Timestep 60 | Loss 0.729788
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:24	Epoch 0 | Batch 70/158 | Timestep 70 | Loss 0.408622
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:25	Epoch 0 | Batch 80/158 | Timestep 80 | Loss 0.204034
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:26	Epoch 0 | Batch 90/158 | Timestep 90 | Loss 0.509178
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:27	Epoch 0 | Batch 100/158 | Timestep 100 | Loss 0.540815
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:28	Epoch 0 | Batch 110/158 | Timestep 110 | Loss 0.371277
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:29	Epoch 0 | Batch 120/158 | Timestep 120 | Loss 0.178164
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:30	Epoch 0 | Batch 130/158 | Timestep 130 | Loss 0.170249
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:31	Epoch 0 | Batch 140/158 | Timestep 140 | Loss 0.156430
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:32	Epoch 0 | Batch 150/158 | Timestep 150 | Loss 0.185966
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:33	** Evaluating on validation dataset **
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:34
#               precision    recall  f1-score   support
#
#     Negative       0.77      0.91      0.84        90
#     Positive       0.89      0.73      0.80        90
#
#     accuracy                           0.82       180
#    macro avg       0.83      0.82      0.82       180
# weighted avg       0.83      0.82      0.82       180
#
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:34	Epoch 0 | Timestep 158 | Train Loss 0.467731 | Val Loss 0.395948 | F1 Micro 0.822222
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:34	** Validation improved, evaluating test data **
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:35
#               precision    recall  f1-score   support
#
#     Negative       0.85      0.96      0.90       178
#     Positive       0.96      0.83      0.89       182
#
#     accuracy                           0.89       360
#    macro avg       0.90      0.90      0.89       360
# weighted avg       0.90      0.89      0.89       360
#
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:35	Epoch 0 | Timestep 158 | Test Loss 0.288397 | F1 Micro 0.894444
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:35	Saving checkpoint to /content/output/model.pt
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:44	Epoch 1 | Batch 2/158 | Timestep 160 | Loss 0.254201
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:45	Epoch 1 | Batch 12/158 | Timestep 170 | Loss 0.392796
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:47	Epoch 1 | Batch 22/158 | Timestep 180 | Loss 0.126760
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:47	Epoch 1 | Batch 32/158 | Timestep 190 | Loss 0.110933
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:48	Epoch 1 | Batch 42/158 | Timestep 200 | Loss 0.375376
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:49	Epoch 1 | Batch 52/158 | Timestep 210 | Loss 0.130070
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:51	Epoch 1 | Batch 62/158 | Timestep 220 | Loss 0.173817
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:52	Epoch 1 | Batch 72/158 | Timestep 230 | Loss 0.434032
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:53	Epoch 1 | Batch 82/158 | Timestep 240 | Loss 0.044103
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:54	Epoch 1 | Batch 92/158 | Timestep 250 | Loss 0.281815
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:55	Epoch 1 | Batch 102/158 | Timestep 260 | Loss 0.085599
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:55	Epoch 1 | Batch 112/158 | Timestep 270 | Loss 0.018319
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:56	Epoch 1 | Batch 122/158 | Timestep 280 | Loss 0.412519
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:57	Epoch 1 | Batch 132/158 | Timestep 290 | Loss 0.132541
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:55:59	Epoch 1 | Batch 142/158 | Timestep 300 | Loss 0.203386
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:00	Epoch 1 | Batch 152/158 | Timestep 310 | Loss 0.705111
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:00	** Evaluating on validation dataset **
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:01
#               precision    recall  f1-score   support
#
#     Negative       0.93      0.84      0.88        90
#     Positive       0.86      0.93      0.89        90
#
#     accuracy                           0.89       180
#    macro avg       0.89      0.89      0.89       180
# weighted avg       0.89      0.89      0.89       180
#
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:01	Epoch 1 | Timestep 316 | Train Loss 0.279405 | Val Loss 0.459679 | F1 Micro 0.888889
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:01	Epoch 2 | Batch 4/158 | Timestep 320 | Loss 0.121434
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:02	Epoch 2 | Batch 14/158 | Timestep 330 | Loss 0.026208
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:03	Epoch 2 | Batch 24/158 | Timestep 340 | Loss 0.011071
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:04	Epoch 2 | Batch 34/158 | Timestep 350 | Loss 0.607628
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:06	Epoch 2 | Batch 44/158 | Timestep 360 | Loss 0.921719
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:07	Epoch 2 | Batch 54/158 | Timestep 370 | Loss 0.636555
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:07	Epoch 2 | Batch 64/158 | Timestep 380 | Loss 0.356986
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:08	Epoch 2 | Batch 74/158 | Timestep 390 | Loss 0.540196
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:09	Epoch 2 | Batch 84/158 | Timestep 400 | Loss 0.393856
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:10	Epoch 2 | Batch 94/158 | Timestep 410 | Loss 0.640419
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:11	Epoch 2 | Batch 104/158 | Timestep 420 | Loss 1.793672
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:12	Epoch 2 | Batch 114/158 | Timestep 430 | Loss 0.685244
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:14	Epoch 2 | Batch 124/158 | Timestep 440 | Loss 0.695974
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:15	Epoch 2 | Batch 134/158 | Timestep 450 | Loss 0.685395
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:16	Epoch 2 | Batch 144/158 | Timestep 460 | Loss 0.759856
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:17	Epoch 2 | Batch 154/158 | Timestep 470 | Loss 0.660105
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:17	** Evaluating on validation dataset **
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:18
#               precision    recall  f1-score   support
#
#     Negative       0.50      1.00      0.67        90
#     Positive       0.00      0.00      0.00        90
#
#     accuracy                           0.50       180
#    macro avg       0.25      0.50      0.33       180
# weighted avg       0.25      0.50      0.33       180
#
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:18	Epoch 2 | Timestep 474 | Train Loss 0.524898 | Val Loss 0.696826 | F1 Micro 0.500000
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:18	Epoch 3 | Batch 6/158 | Timestep 480 | Loss 0.635837
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:19	Epoch 3 | Batch 16/158 | Timestep 490 | Loss 0.772715
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:20	Epoch 3 | Batch 26/158 | Timestep 500 | Loss 0.825573
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:21	Epoch 3 | Batch 36/158 | Timestep 510 | Loss 0.786727
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:23	Epoch 3 | Batch 46/158 | Timestep 520 | Loss 0.706139
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:24	Epoch 3 | Batch 56/158 | Timestep 530 | Loss 0.730384
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:25	Epoch 3 | Batch 66/158 | Timestep 540 | Loss 0.731009
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:26	Epoch 3 | Batch 76/158 | Timestep 550 | Loss 0.705001
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:27	Epoch 3 | Batch 86/158 | Timestep 560 | Loss 0.750064
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:28	Epoch 3 | Batch 96/158 | Timestep 570 | Loss 0.652791
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:29	Epoch 3 | Batch 106/158 | Timestep 580 | Loss 0.667337
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:30	Epoch 3 | Batch 116/158 | Timestep 590 | Loss 0.638019
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:31	Epoch 3 | Batch 126/158 | Timestep 600 | Loss 0.647354
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:32	Epoch 3 | Batch 136/158 | Timestep 610 | Loss 0.682711
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:33	Epoch 3 | Batch 146/158 | Timestep 620 | Loss 0.678796
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:34	Epoch 3 | Batch 156/158 | Timestep 630 | Loss 0.725018
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:34	** Evaluating on validation dataset **
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:35
#               precision    recall  f1-score   support
#
#     Negative       0.50      1.00      0.67        90
#     Positive       0.00      0.00      0.00        90
#
#     accuracy                           0.50       180
#    macro avg       0.25      0.50      0.33       180
# weighted avg       0.25      0.50      0.33       180
#
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:56:35	Epoch 3 | Timestep 632 | Train Loss 0.725044 | Val Loss 0.696740 | F1 Micro 0.500000
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
