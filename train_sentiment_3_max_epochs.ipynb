# %%
# Verify that you have the GPU recognized
# !nvidia-smi
# Out:
# Fri Mar 14 21:35:59 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# # Git clone COMP9312 repo

# %%
# !rm -rf /content/COMP9312
# !git clone https://github.com/mohammedkhalilia/COMP9312.git
# Out:
# Cloning into 'COMP9312'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 107 (delta 19), reused 55 (delta 14), pack-reused 43 (from 1)
# Receiving objects: 100% (107/107), 276.57 KiB | 8.64 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %% [markdown]
# # Install dependencies

# %%
# !pip install transformers==4.40.2
# !pip install seqeval==1.2.2
# !pip install torchtext==0.18.0
# !pip install torchvision==0.17.2
# !pip install torch==2.3.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 62.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 95.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.0
#     Uninstalling tokenizers-0.21.0:
#       Successfully uninstalled tokenizers-0.21.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.48.3
#     Uninstalling transformers-4.48.3:
#       Successfully uninstalled transformers-4.48.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.40.2 which is incompatible.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Model training

# %%
# Make output directory
# !mkdir /content/output/

# %%
import sys
import argparse
sys.path.append('/content/COMP9312/')

# %%
from comp9312.classify.train import main
# Out:
# /usr/local/lib/python3.11/dist-packages/torchtext/vocab/__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# /usr/local/lib/python3.11/dist-packages/torchtext/utils.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)

# %%
# Hyperparameters you can tune include:
#  max_epochs: number of epochs for trianing the model
#  batch_size: size of the batch depending on how much memory you have
#  learning_rate: try small changes for the learning rate, i.e. 0.00002, 0.00003. 0.00004, 0.00005
#  bert_model: there are many different pre-trained BERT models for Arabic and I encourage you try different ones, this includes:
#              1. aubmindlab/bert-base-arabertv2
#              2. UBC-NLP/ARBERTv2
#              3. UBC-NLP/MARBERT
#              4. CAMeL-Lab/bert-base-arabic-camelbert-da
#              5. CAMeL-Lab/bert-base-arabic-camelbert-mix-ner


args_dict = {
    "output_path": "/content/output/",
    "train_path": "/content/COMP9312/comp9312/data/AJGT/train.csv",
    "test_path": "/content/COMP9312/comp9312/data/AJGT/test.csv",
    "val_path": "/content/COMP9312/comp9312/data/AJGT/val.csv",
    "seed": 1,
    "max_epochs": 3,
    "batch_size": 8,
    "bert_model": "aubmindlab/bert-base-arabertv2",
    "num_workers": 1,
    "gpus": [0],
    "learning_rate": .00005
}
args = argparse.Namespace()
args.__dict__ = args_dict

# %%
main(args)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/611 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/720k [00:00<?, ?B/s]
# ...

# %%
# Hyperparameters you can tune include:
#  max_epochs: number of epochs for trianing the model
#  batch_size: size of the batch depending on how much memory you have
#  learning_rate: try small changes for the learning rate, i.e. 0.00002, 0.00003. 0.00004, 0.00005
#  bert_model: there are many different pre-trained BERT models for Arabic and I encourage you try different ones, this includes:
#              1. aubmindlab/bert-base-arabertv2
#              2. UBC-NLP/ARBERTv2
#              3. UBC-NLP/MARBERT
#              4. CAMeL-Lab/bert-base-arabic-camelbert-da
#              5. CAMeL-Lab/bert-base-arabic-camelbert-mix-ner


args_dict = {
    "output_path": "/content/output/",
    "train_path": "/content/COMP9312/comp9312/data/AJGT/train.csv",
    "test_path": "/content/COMP9312/comp9312/data/AJGT/test.csv",
    "val_path": "/content/COMP9312/comp9312/data/AJGT/val.csv",
    "seed": 1,
    "max_epochs": 3,
    "batch_size": 8,
    "bert_model": "aubmindlab/bert-base-arabertv2",
    "num_workers": 1,
    "gpus": [0],
    "learning_rate": .000075
}
args = argparse.Namespace()
args.__dict__ = args_dict

# %%
main(args)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:48:22	Epoch 0 | Batch 10/158 | Timestep 10 | Loss 0.826722
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:48:24	Epoch 0 | Batch 20/158 | Timestep 20 | Loss 0.834243
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:48:24	Epoch 0 | Batch 30/158 | Timestep 30 | Loss 0.585980
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:48:25	Epoch 0 | Batch 40/158 | Timestep 40 | Loss 0.196167
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:48:26	Epoch 0 | Batch 50/158 | Timestep 50 | Loss 0.552104
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:48:27	Epoch 0 | Batch 60/158 | Timestep 60 | Loss 0.475476
# ...

# %%
# Hyperparameters you can tune include:
#  max_epochs: number of epochs for trianing the model
#  batch_size: size of the batch depending on how much memory you have
#  learning_rate: try small changes for the learning rate, i.e. 0.00002, 0.00003. 0.00004, 0.00005
#  bert_model: there are many different pre-trained BERT models for Arabic and I encourage you try different ones, this includes:
#              1. aubmindlab/bert-base-arabertv2
#              2. UBC-NLP/ARBERTv2
#              3. UBC-NLP/MARBERT
#              4. CAMeL-Lab/bert-base-arabic-camelbert-da
#              5. CAMeL-Lab/bert-base-arabic-camelbert-mix-ner


args_dict = {
    "output_path": "/content/output/",
    "train_path": "/content/COMP9312/comp9312/data/AJGT/train.csv",
    "test_path": "/content/COMP9312/comp9312/data/AJGT/test.csv",
    "val_path": "/content/COMP9312/comp9312/data/AJGT/val.csv",
    "seed": 1,
    "max_epochs": 3,
    "batch_size": 8,
    "bert_model": "aubmindlab/bert-base-arabertv2",
    "num_workers": 1,
    "gpus": [0],
    "learning_rate": .0001
}
args = argparse.Namespace()
args.__dict__ = args_dict

# %%
main(args)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:49:24	Epoch 0 | Batch 10/158 | Timestep 10 | Loss 0.861171
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:49:25	Epoch 0 | Batch 20/158 | Timestep 20 | Loss 0.815177
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:49:26	Epoch 0 | Batch 30/158 | Timestep 30 | Loss 0.537471
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:49:27	Epoch 0 | Batch 40/158 | Timestep 40 | Loss 0.322932
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:49:28	Epoch 0 | Batch 50/158 | Timestep 50 | Loss 0.316682
# INFO	comp9312.classify.trainer	Fri, 14 Mar 2025 21:49:29	Epoch 0 | Batch 60/158 | Timestep 60 | Loss 0.729788
# ...
